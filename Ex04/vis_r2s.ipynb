# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

plt.rcParams['figure.figsize'] = (12, 5)

# %%
def read_file(filename):
    size = []
    blocks = []
    threads = []
    bandwidth = []
    with open(filename) as file:
        for line in file:
            if line[0:21] == 'Copy register->shared':
                bois = re.search(r'.*size=\s*(.+?), gDim=\s*(.+?), bDim=\s*(.+?), bw=\s*(.+?)GB/s', line)
                size.append(bois.group(1))
                blocks.append(bois.group(2))
                threads.append(bois.group(3))
                bandwidth.append(bois.group(4))

    data = np.zeros((len(size), 4))
    data[:, 0] = size
    data[:, 1] = blocks
    data[:, 2] = threads
    data[:, 3] = bandwidth

    df = pd.DataFrame(data)
    df.columns = ['size', 'blocks', 'threads', 'bandwidth']

    #df['blocks'] = df['blocks'].astype(int)
    return df

# %%
# find best thread number
df = read_file('4_2_r2s.txt')

for blocks in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
    data_for_block = df[df['blocks'] == blocks]
    plt.plot(data_for_block['size'], data_for_block['bandwidth'], marker='x', linestyle='--', label=f'{blocks} Threads')

plt.xlabel('Size in Bytes')
plt.ylabel('Bandwidth GB/s')
plt.title('Register2Shared: Bandwidth for one Block with various Threads-per-Block size')
plt.legend()
plt.savefig('r2s.png')
